# %%
import os
#os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
#os.environ["CUDA_VISIBLE_DEVICES"]="1" #model will be trained on GPU 1
#import cv2
from keras.layers import Input,Dense,Flatten,Dropout,merge,Reshape,Conv2D,MaxPooling2D,UpSampling2D,Conv2DTranspose
from keras.layers.normalization import BatchNormalization
from keras.models import Model,Sequential
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adadelta, RMSprop,SGD,Adam
from keras import regularizers
from keras import backend as K

# %%
import numpy as np
import scipy.misc
import numpy.random as rng
from PIL import Image, ImageDraw, ImageFont
from sklearn.utils import shuffle
import nibabel as nib #reading MR images
from sklearn.model_selection import train_test_split
from skimage.transform import resize
import math
import glob
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
ff = glob.glob('../SampleXrayImages/80177/view1/*')
ff[0]
ffTest = glob.glob('../SampleXrayImages/80177/view1/anomaly/*')
# Out:
# '../SampleXrayImages/80177/view1/18 128 1523 61 12525 3.jpg'

# %%
len(ff)
# Out:
# 66

# %%
images = []
imagesTest = []

# %%
for f in range(len(ff)):
    #print(ff[f])
    a = Image.open(ff[f])
    a = np.array(a)
    a = resize(a, (a.shape[0] / 4, a.shape[1] / 4),
                       anti_aliasing=True)
    
    #a = a[:,:]
    #for i in range(a.shape[1]):
    images.append(a[:,:,0])
print (a.shape)
# Out:
# /home/wsmonroe/.conda/envs/distributedLearning/lib/python3.6/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# (256, 256, 3)

# %%
for f in range(len(ffTest)):
    #print(ff[f])
    a = Image.open(ffTest[f])
    a = np.array(a)
    a = resize(a, (a.shape[0] / 4, a.shape[1] / 4),
                       anti_aliasing=True)
    
    #a = a[:,:]
    #for i in range(a.shape[1]):
    imagesTest.append(a[:,:,0])
print (a.shape)

# %%
images = np.array(images)
images = np.array(imagesTest)

# %%
images.shape
# Out:
# (66, 256, 256)

# %%
images = images.reshape(-1, 256,256,1)
imagesTest = imagesTest.reshape(-1, 256,256,1)

# %%
images.shape
# Out:
# (66, 256, 256, 1)

# %%
m = np.max(images)
mi = np.min(images)

# %%
m, mi
# Out:
# (0.996078431372549, 0.017647058823533422)

# %%
images = (images - mi) / (m - mi)

# %%
np.min(images), np.max(images)
# Out:
# (0.0, 1.0)

# %%
m = np.max(imagesTest)
mi = np.min(imagesTest)
imagesTest = (imagesTest - mi) / (m - mi)

# %%
from sklearn.model_selection import train_test_split
train_X,valid_X,train_ground,valid_ground = train_test_split(images,
                                                             images,
                                                             test_size=0.2,
                                                             random_state=13)

# %%
# Shapes of training set
print("Dataset (images) shape: {shape}".format(shape=images.shape))
# Out:
# Dataset (images) shape: (66, 256, 256, 1)

# %%
plt.figure(figsize=[5,5])

# Display the first image in training data
plt.subplot(121)
curr_img = np.reshape(train_X[0], (256,256))
plt.imshow(curr_img, cmap='gray')

# Display the first image in testing data
plt.subplot(122)
curr_img = np.reshape(valid_X[0], (256,256))
plt.imshow(curr_img, cmap='gray')

# %%
batch_size = 11
epochs = 300
inChannel = 1
x, y = 256, 256
input_img = Input(shape = (x, y, inChannel))

# %%
def autoencoder(input_img):
    #encoder
    #input = 28 x 28 x 1 (wide and thin)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img) #28 x 28 x 32
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1) #14 x 14 x 32
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1) #14 x 14 x 64
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2) #7 x 7 x 64
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2) #7 x 7 x 128 (small and thick)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)


    #decoder
    conv4 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv3) #7 x 7 x 128
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    up1 = UpSampling2D((2,2))(conv4) # 14 x 14 x 128
    conv5 = Conv2D(32, (3, 3), activation='relu', padding='same')(up1) # 14 x 14 x 64
    conv5 = BatchNormalization()(conv5)
    conv5 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv5)
    conv5 = BatchNormalization()(conv5)
    up2 = UpSampling2D((2,2))(conv5) # 28 x 28 x 64
    decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(up2) # 28 x 28 x 1
    return decoded

# %%
autoencoderModel = Model(input_img, autoencoder(input_img))
autoencoderModel.compile(loss='mean_squared_error', optimizer = RMSprop())

# %%
autoencoderModel.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 256, 256, 1)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 256, 256, 32)      320
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256, 256, 32)      128
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 256, 256, 32)      9248
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 256, 256, 32)      128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 128, 128, 64)      18496
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 128, 128, 64)      256
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 128, 128, 64)      36928
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 128, 128, 64)      256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 64, 64, 128)       73856
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 64, 64, 128)       512
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 64, 64, 128)       147584
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 64, 64, 128)       512
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 64, 64, 64)        73792
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 64, 64, 64)        256
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 64, 64, 64)        256
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 128, 128, 32)      18464
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 128, 128, 32)      128
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 128, 128, 32)      9248
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 128, 128, 32)      128
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 256, 256, 1)       289
# =================================================================
# Total params: 427,713
# Trainable params: 426,433
# Non-trainable params: 1,280
# _________________________________________________________________

# %%
autoencoder_train = autoencoderModel.fit(train_X, train_ground, batch_size=batch_size,epochs=epochs,verbose=1,validation_data=(valid_X, valid_ground))
# Out:
# Train on 52 samples, validate on 14 samples
# Epoch 1/300
# 52/52 [==============================] - 3s 58ms/step - loss: 0.0936 - val_loss: 0.1015
# Epoch 2/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0200 - val_loss: 0.0282
# Epoch 3/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0164 - val_loss: 0.0140
# Epoch 4/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0113 - val_loss: 0.0090
# Epoch 5/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0147 - val_loss: 0.0113
# Epoch 6/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0088 - val_loss: 0.0104
# Epoch 7/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0340 - val_loss: 0.1417
# Epoch 8/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0122 - val_loss: 0.0924
# Epoch 9/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0100 - val_loss: 0.0477
# Epoch 10/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0090 - val_loss: 0.0329
# Epoch 11/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0092 - val_loss: 0.0256
# Epoch 12/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0067 - val_loss: 0.0125
# Epoch 13/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 0.0134
# Epoch 14/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0118 - val_loss: 0.0188
# Epoch 15/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0062 - val_loss: 0.0206
# Epoch 16/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0061 - val_loss: 0.0122
# Epoch 17/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0071 - val_loss: 0.0266
# Epoch 18/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0064 - val_loss: 0.0113
# Epoch 19/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0081
# Epoch 20/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0061 - val_loss: 0.0219
# Epoch 21/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0074 - val_loss: 0.0144
# Epoch 22/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 0.0131
# Epoch 23/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.0212
# Epoch 24/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0058 - val_loss: 0.0097
# Epoch 25/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0052 - val_loss: 0.0163
# Epoch 26/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0038 - val_loss: 0.0159
# Epoch 27/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0093
# Epoch 28/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 0.0143
# Epoch 29/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0076 - val_loss: 0.3727
# Epoch 30/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0058 - val_loss: 0.0194
# Epoch 31/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0034 - val_loss: 0.0114
# Epoch 32/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0162
# Epoch 33/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0153
# Epoch 34/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0046 - val_loss: 0.1453
# Epoch 35/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0049 - val_loss: 0.0363
# Epoch 36/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0176
# Epoch 37/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0182
# Epoch 38/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 0.0361
# Epoch 39/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 0.0635
# Epoch 40/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0039 - val_loss: 0.0239
# Epoch 41/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0228
# Epoch 42/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0255
# Epoch 43/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0192
# Epoch 44/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0222
# Epoch 45/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0028 - val_loss: 0.0212
# Epoch 46/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0032 - val_loss: 0.0119
# Epoch 47/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0035 - val_loss: 0.0173
# Epoch 48/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0218
# Epoch 49/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0394
# Epoch 50/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0036 - val_loss: 0.0159
# Epoch 51/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0246
# Epoch 52/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0216
# Epoch 53/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0146
# Epoch 54/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0184
# Epoch 55/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0268
# Epoch 56/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0113
# Epoch 57/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0231
# Epoch 58/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0187
# Epoch 59/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0154
# Epoch 60/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0185
# Epoch 61/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0140
# Epoch 62/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0247
# Epoch 63/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 0.0176
# Epoch 64/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 0.0190
# Epoch 65/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0157
# Epoch 66/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 0.0269
# Epoch 67/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0147
# Epoch 68/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0135
# Epoch 69/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0141
# Epoch 70/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0165
# Epoch 71/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0109
# Epoch 72/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0244
# Epoch 73/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0120
# Epoch 74/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0105
# Epoch 75/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0112
# Epoch 76/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0167
# Epoch 77/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0179
# Epoch 78/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0091
# Epoch 79/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0281
# Epoch 80/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 0.0109
# Epoch 81/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0173
# Epoch 82/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0083
# Epoch 83/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0089
# Epoch 84/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0093
# Epoch 85/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0069
# Epoch 86/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 0.0099
# Epoch 87/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0061
# Epoch 88/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0097
# Epoch 89/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 0.0087
# Epoch 90/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 0.0115
# Epoch 91/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0082
# Epoch 92/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0100
# Epoch 93/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0078
# Epoch 94/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0063
# Epoch 95/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0078
# Epoch 96/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0057
# Epoch 97/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0128
# Epoch 98/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0768
# Epoch 99/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0049
# Epoch 100/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 101/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0065
# Epoch 102/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0051
# Epoch 103/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0038
# Epoch 104/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0055
# Epoch 105/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0047
# Epoch 106/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0087
# Epoch 107/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0058
# Epoch 108/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0053
# Epoch 109/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0044
# Epoch 110/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0101
# Epoch 111/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0041
# Epoch 112/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0047
# Epoch 113/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0040
# Epoch 114/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0037
# Epoch 115/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0060
# Epoch 116/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 0.0050
# Epoch 117/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0035
# Epoch 118/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0041
# Epoch 119/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0030
# Epoch 120/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0042
# Epoch 121/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0048
# Epoch 122/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0062
# Epoch 123/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0030
# Epoch 124/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0086
# Epoch 125/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0041
# Epoch 126/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0.0111
# Epoch 127/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 0.0045
# Epoch 128/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0044
# Epoch 129/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 0.0032
# Epoch 130/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0026
# Epoch 131/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0046
# Epoch 132/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 0.0032
# Epoch 133/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 0
300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 277/300
# 52/52 [==============================] - 0s 7ms/step - loss: 6.8409e-04 - val_loss: 9.9538e-04
# Epoch 278/300
# 52/52 [==============================] - 0s 7ms/step - loss: 7.1065e-04 - val_loss: 0.0018
# Epoch 279/300
# 52/52 [==============================] - 0s 7ms/step - loss: 7.5145e-04 - val_loss: 0.0011
# Epoch 280/300
# 52/52 [==============================] - 0s 7ms/step - loss: 7.4375e-04 - val_loss: 0.0011
# Epoch 281/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 282/300
# 52/52 [==============================] - 0s 7ms/step - loss: 6.7097e-04 - val_loss: 0.0018
# Epoch 283/300
# 52/52 [==============================] - 0s 7ms/step - loss: 7.2758e-04 - val_loss: 0.0023
# Epoch 284/300
# 52/52 [==============================] - 0s 7ms/step - loss: 6.9622e-04 - val_loss: 0.0022
# Epoch 285/300
# 52/52 [==============================] - 0s 7ms/step - loss: 6.8609e-04 - val_loss: 9.4334e-04
# Epoch 286/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 0.0049
# Epoch 287/300
# 52/52 [==============================] - 0s 7ms/step - loss: 8.8690e-04 - val_loss: 0.0032
# Epoch 288/300
# 52/52 [==============================] - 0s 7ms/step - loss: 7.4392e-04 - val_loss: 0.0025
# Epoch 289/300
# 52/52 [==============================] - 0s 7ms/step - loss: 7.0119e-04 - val_loss: 0.0015
# Epoch 290/300
# 52/52 [==============================] - 0s 7ms/step - loss: 8.3354e-04 - val_loss: 0.0021
# Epoch 291/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0022
# Epoch 292/300
# 52/52 [==============================] - 0s 7ms/step - loss: 5.9447e-04 - val_loss: 0.0015
# Epoch 293/300
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.2708
# Epoch 294/300
# 52/52 [==============================] - 0s 7ms/step - loss: 7.8133e-04 - val_loss: 0.1962
# Epoch 295/300
# 52/52 [==============================] - 0s 7ms/step - loss: 7.6676e-04 - val_loss: 0.1281
# Epoch 296/300
# 52/52 [==============================] - 0s 7ms/step - loss: 7.2050e-04 - val_loss: 0.0019
# Epoch 297/300
# 52/52 [==============================] - 0s 7ms/step - loss: 5.7260e-04 - val_loss: 0.0038
# Epoch 298/300
# 52/52 [==============================] - 0s 7ms/step - loss: 7.1673e-04 - val_loss: 0.0018
# Epoch 299/300
# 52/52 [==============================] - 0s 7ms/step - loss: 5.5896e-04 - val_loss: 0.0019
# Epoch 300/300
# 52/52 [==============================] - 0s 7ms/step - loss: 8.8366e-04 - val_loss: 0.0019

# %%
loss = autoencoder_train.history['loss']
val_loss = autoencoder_train.history['val_loss']
epochs = range(300)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
autoencoderOut = autoencoderModel.save_weights('autoencoder_xray.h5')

# %%
autoencoderRebuild = Model(input_img, autoencoder(input_img))

# %%
autoencoderRebuild.load_weights('autoencoder_xray.h5')

# %%
pred = autoencoderRebuild.predict(imagesTest)

# %%
plt.figure(figsize=(20, 4))
print("Test Images")
for i in range(5):
    plt.subplot(1, 5, i+1)
    plt.imshow(valid_ground[i, ..., 0], cmap='gray')
plt.show()    
plt.figure(figsize=(20, 4))
print("Reconstruction of Test Images")
for i in range(5):
    plt.subplot(1, 5, i+1)
    plt.imshow(pred[i, ..., 0], cmap='gray')  
plt.show()
plt.figure(figsize=(20, 4))
print("Difference of Images")
for i in range(5):
    plt.subplot(1, 5, i+1)
    plt.imshow(pred[i, ..., 0]-valid_ground[i,...,0], cmap='gray') 
plt.show()
# Out:
# Test Images
# Reconstruction of Test Images
# Difference of Images
